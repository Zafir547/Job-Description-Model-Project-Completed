# %% [markdown]
# # **Import Libraries and Setup**

# %%
import os
import re
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

import nltk
import spacy
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords


from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity

# Ensure required NLTK packages are downloaded
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\zafir\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # **1. Load the Dataset**

# %%
df = pd.read_csv("job_description_subset_first.csv")

# %%
df
# Out:
#                  Job Id     Experience Qualifications Salary Range  \
# 0      1089843540111562  5 to 15 Years         M.Tech    $59K-$99K
# 1       398454096642776  2 to 12 Years            BCA   $56K-$116K
# 2       481640072963533  0 to 12 Years            PhD   $61K-$104K
# 3       688192671473044  4 to 11 Years            PhD    $65K-$91K
# 4       117057806156508  1 to 12 Years            MBA    $64K-$87K
# ...                 ...            ...            ...          ...
# 14995   294966963537218   3 to 9 Years         B.Tech    $65K-$96K
# 14996  1364760048987040  3 to 11 Years          M.Com   $55K-$116K
# 14997  1828052769874683   0 to 8 Years          M.Com   $62K-$104K
# 14998   597132853070793   5 to 8 Years          B.Com   $56K-$106K
# 14999  1865118033271097  3 to 14 Years             BA    $63K-$81K
#
#                  location           Country  latitude  longitude  Work Type  \
# 0                 Douglas       Isle of Man   54.2361    -4.5481     Intern
# 1                Ashgabat      Turkmenistan   38.9697    59.5563     Intern
# 2                   Macao  Macao SAR, China   22.1987   113.5439  Temporary
# 3              Porto-Novo             Benin    9.3077     2.3158  Full-Time
# 4                Santiago             Chile  -35.6751   -71.5429     Intern
# ...                   ...               ...       ...        ...        ...
# 14995  City of Port Louis         Mauritius  -20.3484    57.5522  Temporary
# 14996          Willemstad           Curacao   12.1696   -68.9900  Full-Time
# 14997              Prague    Czech Republic   49.8175    15.4730  Part-Time
# 14998                Baku        Azerbaijan   40.1431    47.5769     Intern
# 14999              Gitega           Burundi   -3.3731    29.9189     Intern
#
#        Company Size  ...                Contact  \
# 0             26801  ...   001-381-930-7517x737
# 1            100340  ...           461-509-4216
# 2             84525  ...             9687619505
# 3            129896  ...  +1-820-643-5431x47576
# 4             53944  ...      343.975.4702x9340
# ...             ...  ...                    ...
# 14995         31536  ...       824-652-9619x801
# 14996        134005  ...      844-896-0429x1384
# 14997        117548  ...        +1-635-614-8200
# 14998        115336  ...           953.736.8405
# 14999         60381  ...    (927)514-4994x15587
#
#                              Job Title                       Role  \
# 0         Digital Marketing Specialist       Social Media Manager
# 1                        Web Developer     Frontend Web Developer
# 2                   Operations Manager    Quality Control Manager
# 3                     Network Engineer  Wireless Network Engineer
# 4                        Event Manager         Conference Manager
# ...                                ...                        ...
# 14995                     Web Designer    E-commerce Web Designer
# 14996  Customer Service Representative    Live Chat Support Agent
# 14997                  Software Tester  Quality Assurance Analyst
# 14998            Systems Administrator     Database Administrator
# 14999              Front-End Developer            UI/UX Developer
#
#                 Job Portal                                    Job Description  \
# 0                 Snagajob  Social Media Managers oversee an organizations...
# 1                 Idealist  Frontend Web Developers design and implement u...
# 2             Jobs2Careers  Quality Control Managers establish and enforce...
# 3                 FlexJobs  Wireless Network Engineers design, implement, ...
# 4             Jobs2Careers  A Conference Manager coordinates and manages c...
# ...                    ...                                                ...
# 14995  Stack Overflow Jobs  E-commerce Web Designers specialize in designi...
# 14996          SimplyHired  A Live Chat Support Agent provides customer su...
# 14997  Stack Overflow Jobs  A Quality Assurance Analyst tests software and...
# 14998             FlexJobs  Database Administrators manage databases, ensu...
# 14999             FlexJobs  A UI/UX Developer combines design and technica...
#
#                                                 Benefits  \
# 0      {'Flexible Spending Accounts (FSAs), Relocatio...
# 1      {'Health Insurance, Retirement Plans, Paid Tim...
# 2      {'Legal Assistance, Bonuses and Incentive Prog...
# 3      {'Transportation Benefits, Professional Develo...
# 4      {'Flexible Spending Accounts (FSAs), Relocatio...
# ...                                                  ...
# 14995  {'Flexible Spending Accounts (FSAs), Relocatio...
# 14996  {'Employee Assistance Programs (EAP), Tuition ...
# 14997  {'Transportation Benefits, Professional Develo...
# 14998  {'Casual Dress Code, Social and Recreational A...
# 14999  {'Casual Dress Code, Social and Recreational A...
#
#                                                   skills  \
# 0      Social media platforms (e.g., Facebook, Twitte...
# 1      HTML, CSS, JavaScript Frontend frameworks (e.g...
# 2      Quality control processes and methodologies St...
# 3      Wireless network design and architecture Wi-Fi...
# 4      Event planning Conference logistics Budget man...
# ...                                                  ...
# 14995  E-commerce web design UX/UI design Shopping ca...
# 14996  Live chat support Online customer communicatio...
# 14997  Quality assurance processes Testing methodolog...
# 14998  Database management systems (e.g., MySQL, Orac...
# 14999  User interface (UI) design User experience (UX...
#
#                                         Responsibilities  \
# 0      Manage and grow social media accounts, create ...
# 1      Design and code user interfaces for websites, ...
# 2      Establish and enforce quality control standard...
# 3      Design, configure, and optimize wireless netwo...
# 4      Specialize in conference and convention planni...
# ...                                                  ...
# 14995  Focus on designing user interfaces for e-comme...
# 14996  Offer real-time customer support through live ...
# 14997  Test software applications and systems to iden...
# 14998  Administer and optimize databases, ensuring da...
# 14999  Design and implement user interfaces (UI) for ...
#
#                                 Company  \
# 0                     Icahn Enterprises
# 1          PNC Financial Services Group
# 2      United Services Automobile Assn.
# 3                                  Hess
# 4                          Cairn Energy
# ...                                 ...
# 14995                     Valero Energy
# 14996                          HDFC Ltd
# 14997                     Alibaba Group
# 14998          Glenmark Pharmaceuticals
# 14999               Telstra Corporation
#
#                                          Company Profile
# 0      {"Sector":"Diversified","Industry":"Diversifie...
# 1      {"Sector":"Financial Services","Industry":"Com...
# 2      {"Sector":"Insurance","Industry":"Insurance: P...
# 3      {"Sector":"Energy","Industry":"Mining, Crude-O...
# 4      {"Sector":"Energy","Industry":"Energy - Oil & ...
# ...                                                  ...
# 14995  {"Sector":"Energy","Industry":"Petroleum Refin...
# 14996  {"Sector":"Financial Services","Industry":"Ban...
# 14997  {"Sector":"E-commerce","Industry":"E-commerce ...
# 14998  {"Sector":"Pharmaceuticals","Industry":"Pharma...
# 14999  {"Sector":"Telecommunications","Industry":"Tel...
#
# [15000 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Job Id            15000 non-null  int64
#  1   Experience        15000 non-null  object
#  2   Qualifications    15000 non-null  object
#  3   Salary Range      15000 non-null  object
#  4   location          15000 non-null  object
#  5   Country           15000 non-null  object
#  6   latitude          15000 non-null  float64
#  7   longitude         15000 non-null  float64
#  8   Work Type         15000 non-null  object
#  9   Company Size      15000 non-null  int64
#  10  Job Posting Date  15000 non-null  object
#  11  Preference        15000 non-null  object
#  12  Contact Person    15000 non-null  object
#  13  Contact           15000 non-null  object
#  14  Job Title         15000 non-null  object
#  15  Role              15000 non-null  object
#  16  Job Portal        15000 non-null  object
#  17  Job Description   15000 non-null  object
#  18  Benefits          15000 non-null  object
#  19  skills            15000 non-null  object
#  20  Responsibilities  15000 non-null  object
#  21  Company           15000 non-null  object
#  22  Company Profile   14947 non-null  object
# dtypes: float64(2), int64(2), object(19)
# memory usage: 2.6+ MB

# %%
df.describe()
# Out:
#              Job Id      latitude     longitude   Company Size
# count  1.500000e+04  15000.000000  15000.000000   15000.000000
# mean   1.552358e+15     18.913126     15.935685   73682.708267
# std    8.943545e+14     23.452494     71.482840   35480.644565
# min    2.018175e+11    -40.900600   -175.198200   12675.000000
# 25%    7.724910e+14      4.570900    -15.310100   42591.000000
# 50%    1.558861e+15     17.607800     19.374400   73961.000000
# 75%    2.323712e+15     38.969700     48.516400  104234.000000
# max    3.099079e+15     71.706900    178.065000  134831.000000

# %%
df.shape
# Out:
# (15000, 23)

# %%
df.size
# Out:
# 345000

# %%
df.columns
# Out:
# Index(['Job Id', 'Experience', 'Qualifications', 'Salary Range', 'location',
#        'Country', 'latitude', 'longitude', 'Work Type', 'Company Size',
#        'Job Posting Date', 'Preference', 'Contact Person', 'Contact',
#        'Job Title', 'Role', 'Job Portal', 'Job Description', 'Benefits',
#        'skills', 'Responsibilities', 'Company', 'Company Profile'],
#       dtype='object')

# %% [markdown]
# # **2. Data Cleaning and Preparation**

# %% [markdown]
# ### **1. Handling Duplicate Data**

# %%
df.isnull().sum()
# Out:
# Job Id               0
# Experience           0
# Qualifications       0
# Salary Range         0
# location             0
# Country              0
# latitude             0
# longitude            0
# Work Type            0
# Company Size         0
# Job Posting Date     0
# Preference           0
# Contact Person       0
# Contact              0
# Job Title            0
# Role                 0
# Job Portal           0
# Job Description      0
# Benefits             0
# skills               0
# Responsibilities     0
# Company              0
# Company Profile     53
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# Job Id                int64
# Experience           object
# Qualifications       object
# Salary Range         object
# location             object
# Country              object
# latitude            float64
# longitude           float64
# Work Type            object
# Company Size          int64
# Job Posting Date     object
# Preference           object
# Contact Person       object
# Contact              object
# Job Title            object
# Role                 object
# Job Portal           object
# Job Description      object
# Benefits             object
# skills               object
# Responsibilities     object
# Company              object
# Company Profile      object
# dtype: object

# %%
df.columns
# Out:
# Index(['Job Id', 'Experience', 'Qualifications', 'Salary Range', 'location',
#        'Country', 'latitude', 'longitude', 'Work Type', 'Company Size',
#        'Job Posting Date', 'Preference', 'Contact Person', 'Contact',
#        'Job Title', 'Role', 'Job Portal', 'Job Description', 'Benefits',
#        'skills', 'Responsibilities', 'Company', 'Company Profile'],
#       dtype='object')

# %%
# Filling null values with mode
for column in df.select_dtypes(include=['object']).columns:  # Select only categorical columns
    if df[column].isnull().any():  # Check if the column has any missing values
        df[column] = df[column].fillna(df[column].mode()[0])  # Fill with mode

# %%
df.isnull().sum()
# Out:
# Job Id              0
# Experience          0
# Qualifications      0
# Salary Range        0
# location            0
# Country             0
# latitude            0
# longitude           0
# Work Type           0
# Company Size        0
# Job Posting Date    0
# Preference          0
# Contact Person      0
# Contact             0
# Job Title           0
# Role                0
# Job Portal          0
# Job Description     0
# Benefits            0
# skills              0
# Responsibilities    0
# Company             0
# Company Profile     0
# dtype: int64

# %%
# Remove duplicate rows
df.drop_duplicates(inplace=True)
print("Shape after removing duplicates:", df.shape)
# Out:
# Shape after removing duplicates: (15000, 23)

# %% [markdown]
# ### **2. Handling Missing Data**

# %%
# Drop rows with missing job_description or job_title
df.dropna(subset=["Job Description", "Job Title"], inplace=True) # Drop rows where critical fields are missing
print("Shape after dropping rows with missing values:", df.shape)
# Out:
# Shape after dropping rows with missing values: (15000, 23)

# %% [markdown]
# # **3. Handling Outliers Based on Job Description Word Count**

# %%
desc_length = df["Job Description"].apply(lambda x: len(str(x).split()))
q1, q3 = np.percentile(desc_length, [25, 75])
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
df = df[(desc_length >= lower_bound) & (desc_length <= upper_bound)]
print("Shape after handling outliers:", df.shape)
# Out:
# Shape after handling outliers: (14659, 23)

# %% [markdown]
# # **4. Text Cleaning with spaCy & NLTK (Lemmatization and Stemming)**

# %%
# Load spaCy model (Enable GPU if available)
# Enable GPU for spaCy (raises error if no GPU is available)
try:
    spacy.require_gpu()
    print("Using GPU for spaCy processing.")
except:
    print("No GPU available, using CPU.")
# Out:
# Using GPU for spaCy processing.

# %%
# Initialize spaCy model and NLTK's PorterStemmer
nlp = spacy.load("en_core_web_sm")
stemmer = PorterStemmer()
stop_words = set(stopwords.words("english"))

# %%
def clean_text_preprocess(text):
    """
    Preprocess the input text by:
      - Converting to lowercase.
      - Removing HTML tags.
      - Removing non-alphabetical characters.
      - Removing extra whitespace.
      - Removing stopwords.
    """
    text = text.lower()
    text = re.sub(r"<[^>]+>", " ", text)  # Remove HTML tags
    text = re.sub(r"[^a-z\s]", " ", text)  # Keep only alphabets
    text = re.sub(r"\s+", " ", text).strip()  # Remove extra spaces
    text = " ".join([word for word in text.split() if word not in stop_words])  # Remove stopwords
    return text

# %%
# If you have any RAM requirement—8 GB, 16 GB, 32 GB, or 64 GB—you can replace batch_size = any GB accordingly
def clean_text_batch(texts, batch_size=32):
    """
    Process a list of texts using spaCy's nlp.pipe in batches.
    Applies pre-processing, lemmatization, and stemming.
    
    Args:
        texts (list): List of raw text strings.
        batch_size (int): Batch size for spaCy processing.
        
    Returns:
        list: List of cleaned text strings.
    """
    preprocessed_texts = [clean_text_preprocess(text) for text in texts]
    cleaned_texts = []
    for doc in nlp.pipe(preprocessed_texts, batch_size=batch_size):
        processed_tokens = [stemmer.stem(token.lemma_) for token in doc if token.is_alpha]
        cleaned_texts.append(" ".join(processed_tokens))
    return cleaned_texts

# %%
# If you have any RAM requirement—8 GB, 16 GB, 32 GB, or 64 GB—you can replace batch_size = any GB accordingly
# Apply cleaning in batches or If 
df["Cleaned Job Description"] = clean_text_batch(df["Job Description"].astype(str).tolist(), batch_size=32)

# %%
# Standardize job titles (lowercasing and removing extra spaces)
df["Cleaned Job Title"] = df["Job Title"].apply(lambda x: x.lower().strip())

# %%
print("Preview of cleaned job descriptions and titles:")
df[["Cleaned Job Description", "Cleaned Job Title"]].head()
# Out:
# Preview of cleaned job descriptions and titles:
#                              Cleaned Job Description  \
# 0  social medium manag overse organ social medium...
# 1  frontend web develop design implement user int...
# 2  qualiti control manag establish enforc qualiti...
# 3  wireless network engin design implement mainta...
# 4  confer manag coordin manag confer meet event p...
#
#               Cleaned Job Title
# 0  digital marketing specialist
# 1                 web developer
# 2            operations manager
# 3              network engineer
# 4                 event manager

# %%
# Analyze job title distribution (show top 10)
print("Job title distribution (top 10):")
df["Cleaned Job Title"].value_counts().head(10)
# Out:
# Job title distribution (top 10):
# Cleaned Job Title
# ux/ui designer                  493
# software engineer               260
# digital marketing specialist    244
# network engineer                214
# executive assistant             200
# software tester                 188
# sales representative            183
# procurement manager             178
# financial advisor               176
# customer support specialist     170
# Name: count, dtype: int64

# %% [markdown]
# # **5. Feature Scaling for Salary Range**

# %%
def parse_salary_range(salary_str):
    """
    Converts a salary range string (e.g., "$59K-$99K") into a numeric average.
    Assumes salary values are in 'K' (thousands) and returns the average salary in thousands.
    """
    # Remove dollar signs, 'K', commas, and extra whitespace
    salary_str = salary_str.replace("$", "").replace("K", "").replace(",", "").strip()
    try:
        # Split the range into minimum and maximum parts
        parts = salary_str.split("-")
        if len(parts) == 2:
            salary_min = float(parts[0])
            salary_max = float(parts[1])
            return (salary_min + salary_max) / 2 # Average of min and max
        else:
            return np.nan
    except Exception as e:
        return np.nan

if "Salary Range" in df.columns:
    # Apply the parsing function to create a numeric average salary column
    df["Salary Avg"] = df["Salary Range"].apply(parse_salary_range)

    # Drop rows where the salary couldn't be parsed (optional)
    df.dropna(subset=["Salary Avg"], inplace=True)

    # Scale the numeric salary values using MinMaxScaler
    scaler = MinMaxScaler() # Alternative: StandardScaler()
    df["Scaled Salary"] = scaler.fit_transform(df[["Salary Avg"]])
    
    print("Scaled Salary (first 5 rows):")
    print(df["Scaled Salary"].head())
# Out:
# Scaled Salary (first 5 rows):
# 0    0.383333
# 1    0.616667
# 2    0.500000
# 3    0.350000
# 4    0.266667
# Name: Scaled Salary, dtype: float64

# %% [markdown]
# # **6. ENCODING THE COLUMNS FOR BETTER PREDICTION**

# %% [markdown]
# ### Assume df is your DataFrame

# %%
# Identify categorical columns and remove the column we don't want to encode.
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()
categorical_cols.remove('Job Title')

# %%
# (Optional) Check the number of unique values in each categorical column.
print("Unique values per categorical column:")
for col in categorical_cols:
    print(f"{col}: {df[col].nunique()}")
# Out:
# Unique values per categorical column:
# Experience: 48
# Qualifications: 10
# Salary Range: 561
# location: 214
# Country: 216
# Work Type: 5
# Job Posting Date: 731
# Preference: 3
# Contact Person: 13320
# Contact: 14659
# Role: 366
# Job Portal: 16
# Job Description: 366
# Benefits: 11
# skills: 366
# Responsibilities: 365
# Company: 888
# Company Profile: 884
# Cleaned Job Description: 366
# Cleaned Job Title: 143

# %%
# Use sparse output to prevent memory explosion
encoder = OneHotEncoder(handle_unknown='ignore', drop='first', sparse_output=True)
encoded_data = encoder.fit_transform(df[categorical_cols])

# %%
# Convert sparse matrix to DataFrame
encoded_df = pd.DataFrame.sparse.from_spmatrix(encoded_data, columns=encoder.get_feature_names_out(categorical_cols))

# %%
# (Optional) If you want to merge the encoded features back with the original DataFrame,
# you can drop the original categorical columns and join the new ones.
df_encoded = pd.concat([df.drop(columns=categorical_cols), encoded_df], axis=1)

print("One-hot encoding completed. New DataFrame shape:", df.shape)
# Out:
# One-hot encoding completed. New DataFrame shape: (14659, 27)

# %%
# Drop any remaining NaN values
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Job Id                     0
# Experience                 0
# Qualifications             0
# Salary Range               0
# location                   0
# Country                    0
# latitude                   0
# longitude                  0
# Work Type                  0
# Company Size               0
# Job Posting Date           0
# Preference                 0
# Contact Person             0
# Contact                    0
# Job Title                  0
# Role                       0
# Job Portal                 0
# Job Description            0
# Benefits                   0
# skills                     0
# Responsibilities           0
# Company                    0
# Company Profile            0
# Cleaned Job Description    0
# Cleaned Job Title          0
# Salary Avg                 0
# Scaled Salary              0
# dtype: int64

# %%
df.isnull()
# Out:
#        Job Id  Experience  Qualifications  Salary Range  location  Country  \
# 0       False       False           False         False     False    False
# 1       False       False           False         False     False    False
# 2       False       False           False         False     False    False
# 3       False       False           False         False     False    False
# 4       False       False           False         False     False    False
# ...       ...         ...             ...           ...       ...      ...
# 14995   False       False           False         False     False    False
# 14996   False       False           False         False     False    False
# 14997   False       False           False         False     False    False
# 14998   False       False           False         False     False    False
# 14999   False       False           False         False     False    False
#
#        latitude  longitude  Work Type  Company Size  ...  Job Description  \
# 0         False      False      False         False  ...            False
# 1         False      False      False         False  ...            False
# 2         False      False      False         False  ...            False
# 3         False      False      False         False  ...            False
# 4         False      False      False         False  ...            False
# ...         ...        ...        ...           ...  ...              ...
# 14995     False      False      False         False  ...            False
# 14996     False      False      False         False  ...            False
# 14997     False      False      False         False  ...            False
# 14998     False      False      False         False  ...            False
# 14999     False      False      False         False  ...            False
#
#        Benefits  skills  Responsibilities  Company  Company Profile  \
# 0         False   False             False    False            False
# 1         False   False             False    False            False
# 2         False   False             False    False            False
# 3         False   False             False    False            False
# 4         False   False             False    False            False
# ...         ...     ...               ...      ...              ...
# 14995     False   False             False    False            False
# 14996     False   False             False    False            False
# 14997     False   False             False    False            False
# 14998     False   False             False    False            False
# 14999     False   False             False    False            False
#
#        Cleaned Job Description  Cleaned Job Title  Salary Avg  Scaled Salary
# 0                        False              False       False          False
# 1                        False              False       False          False
# 2                        False              False       False          False
# 3                        False              False       False          False
# 4                        False              False       False          False
# ...                        ...                ...         ...            ...
# 14995                    False              False       False          False
# 14996                    False              False       False          False
# 14997                    False              False       False          False
# 14998                    False              False       False          False
# 14999                    False              False       False          False
#
# [14659 rows x 27 columns]

# %% [markdown]
# # **7. Feature Extraction using TF-IDF for Resume Matching**

# %%
tfidf = TfidfVectorizer(stop_words="english", max_features=5000, binary=True)
X = tfidf.fit_transform(df["Cleaned Job Description"])
print("\nTF-IDF feature matrix shape for job descriptions:", X.shape)
# Out:
# TF-IDF feature matrix shape for job descriptions: (14659, 931)

# %%
X[0].sum()
# Out:
# 3.8934708757719436

# %%
tfidf.get_feature_names_out()
# Out:
# array(['abus', 'academ', 'accept', 'access', 'accordingli', 'account',
#        'accur', 'accuraci', 'achiev', 'acquir', 'acquisit', 'action',
#        'activ', 'acut', 'ad', 'adapt', 'addict', 'address', 'adher',
#        'adjust', 'administ', 'administr', 'adolesc', 'adopt', 'adult',
#        'advanc', 'advers', 'advertis', 'advic', 'advis', 'advisor',
#        'advoc', 'aerodynam', 'aesthet', 'age', 'agenc', 'agent', 'agil',
#        'agreement', 'aid', 'aim', 'air', 'aircraft', 'algorithm', 'align',
#        'allianc', 'alloc', 'analysi', 'analyst', 'analyt', 'analyz',
#        'anim', 'answer', 'anthropolog', 'api', 'app', 'appeal', 'applic',
#        'appreci', 'architect', 'architectur', 'area', 'arrang', 'art',
#        'articl', 'artist', 'artwork', 'aspect', 'assess', 'asset',
#        'assist', 'associ', 'assur', 'attend', 'attende', 'attorney',
#        'attract', 'audienc', 'audit', 'autom', 'avail', 'avion', 'awar',
#        'backend', 'backlog', 'base', 'beauti', 'behavior', 'belong',
#        'benefit', 'big', 'blog', 'board', 'boost', 'bottleneck', 'brand',
#        'breach', 'bridg', 'bring', 'brochur', 'browser', 'budget', 'bug',
#        'build', 'busi', 'button', 'cad', 'calendar', 'campaign', 'candid',
#        'capabl', 'captiv', 'cardiolog', 'care', 'carri', 'case', 'cash',
#        'cat', 'cater', 'cd', 'center', 'centric', 'chain', 'challeng',
#        'chang', 'channel', 'charg', 'chat', 'check', 'chemic', 'child',
#        'ci', 'circuit', 'citi', 'civil', 'classroom', 'clean', 'clear',
#        'clerk', 'client', 'clinic', 'close', 'cloud', 'coach', 'code',
#        'cohes', 'collabor', 'collect', 'color', 'combin', 'comfort',
#        'commerc', 'commerci', 'common', 'commun', 'compani', 'compel',
#        'compet', 'competit', 'competitor', 'complet', 'complex',
#        'complianc', 'compon', 'comprehens', 'comput', 'concept',
#        'conceptu', 'concern', 'condit', 'conduct', 'confer', 'configur',
#        'conflict', 'connect', 'consequ', 'conserv', 'consid', 'consist',
#        'construct', 'consult', 'consum', 'content', 'context', 'continu',
#        'contract', 'contractor', 'contribut', 'control', 'convers',
#        'convey', 'coordin', 'cope', 'copi', 'copyright', 'copywrit',
#        'cor', 'core', 'corpor', 'correct', 'correspond', 'cost',
#        'counsel', 'counselor', 'coupl', 'court', 'coverag', 'craft',
#        'creat', 'creation', 'creativ', 'crimin', 'crisi', 'critic',
#        'cross', 'css', 'curat', 'curriculum', 'custodi', 'custom',
#        'cyber', 'cybersecur', 'daili', 'dam', 'dashboard', 'data',
#        'databas', 'date', 'datum', 'day', 'deal', 'debug', 'decis',
#        'decor', 'deep', 'defect', 'defin', 'deliv', 'deliver', 'deliveri',
#        'demand', 'demonstr', 'dental', 'depart', 'deploy', 'deriv',
#        'design', 'desk', 'desktop', 'detect', 'develop', 'development',
#        'devic', 'devop', 'diagnos', 'diagnosi', 'differ', 'difficulti',
#        'digit', 'dilig', 'directli', 'director', 'disabl', 'discoveri',
#        'discrep', 'discrimin', 'discuss', 'diseas', 'disord', 'disput',
#        'distribut', 'divers', 'divorc', 'doctor', 'document', 'dog',
#        'domain', 'domest', 'draft', 'drafter', 'draw', 'drive', 'duti',
#        'dynam', 'eco', 'edg', 'educ', 'effect', 'effici', 'effort',
#        'elderli', 'electr', 'electron', 'element', 'email', 'emerg',
#        'emot', 'emphasi', 'employ', 'employe', 'enabl', 'end', 'energi',
#        'enforc', 'engag', 'engin', 'enhanc', 'enjoy', 'ensur',
#        'enterpris', 'entertain', 'entri', 'environ', 'environment',
#        'equin', 'equip', 'essenti', 'establish', 'estat', 'etl', 'evalu',
#        'event', 'everi', 'examin', 'excel', 'exchang', 'execut',
#        'exhibit', 'exist', 'exot', 'expand', 'expans', 'expect', 'experi',
#        'expert', 'expertis', 'explain', 'express', 'extern', 'extract',
#        'facil', 'facilit', 'famili', 'featur', 'feedback', 'field',
#        'file', 'financ', 'financi', 'fine', 'firm', 'flight', 'flood',
#        'flow', 'focu', 'follow', 'forecast', 'forens', 'form', 'foster',
#        'framework', 'fraud', 'friendli', 'frontend', 'fulfil', 'function',
#        'furnish', 'furnitur', 'futur', 'gain', 'gap', 'gastroenterolog',
#        'gather', 'gener', 'generalist', 'geriatr', 'global', 'goal',
#        'good', 'googl', 'grade', 'graphic', 'group', 'grow', 'growth',
#        'guid', 'guidanc', 'gum', 'hand', 'handl', 'hardwar', 'health',
#        'healthcar', 'healthi', 'hear', 'heat', 'help', 'high', 'highway',
#        'hire', 'histor', 'home', 'hors', 'hospit', 'hotel', 'hr', 'html',
#        'human', 'hvac', 'hygien', 'hygienist', 'ident', 'identifi', 'ill',
#        'illustr', 'imag', 'impact', 'implement', 'improv', 'incid',
#        'includ', 'inclus', 'incom', 'incorpor', 'increas', 'increment',
#        'independ', 'individu', 'industri', 'infant', 'influenc', 'inform',
#        'infrastructur', 'initi', 'injuri', 'innov', 'input', 'inquiri',
#        'insid', 'insight', 'inspect', 'instal', 'institut', 'instruct',
#        'instructor', 'instrument', 'insur', 'integr', 'intellectu',
#        'intellig', 'interact', 'interfac', 'interior', 'intern',
#        'interperson', 'interpret', 'intervent', 'interview', 'intuit',
#        'inventori', 'invest', 'investig', 'invit', 'involv', 'ip',
#        'irrig', 'issu', 'item', 'java', 'javascript', 'journey', 'judg',
#        'keeper', 'key', 'keyword', 'knowledg', 'labor', 'land',
#        'landscap', 'languag', 'larg', 'launch', 'law', 'lawyer', 'layout',
#        'lead', 'learn', 'legal', 'lesson', 'level', 'leverag', 'liabil',
#        'liais', 'librari', 'life', 'light', 'like', 'line', 'liquid',
#        'list', 'litig', 'live', 'load', 'logic', 'logist', 'long', 'loss',
#        'loyalti', 'machin', 'machineri', 'maintain', 'mainten', 'make',
#        'manag', 'manner', 'manual', 'manufactur', 'market', 'materi',
#        'matter', 'maxim', 'meaning', 'measur', 'mechan', 'media',
#        'mediat', 'medic', 'medium', 'meet', 'member', 'memor', 'mental',
#        'mentor', 'merger', 'messag', 'methodolog', 'metric', 'minim',
#        'mitig', 'mobil', 'model', 'moder', 'modifi', 'monitor', 'motiv',
#        'motor', 'movement', 'mutual', 'nativ', 'navig', 'need', 'negoti',
#        'net', 'network', 'neutral', 'new', 'non', 'nosql', 'nurs',
#        'nurtur', 'object', 'occup', 'offer', 'offic', 'onboard',
#        'oncolog', 'onlin', 'oper', 'opportun', 'optim', 'option', 'oral',
#        'order', 'organ', 'organiz', 'orient', 'orthoped', 'outcom',
#        'outdoor', 'outgo', 'outlet', 'outreach', 'outsid', 'overal',
#        'overcom', 'overse', 'owner', 'packag', 'page', 'pain', 'paint',
#        'parent', 'park', 'parti', 'partnership', 'patent', 'pathologist',
#        'patient', 'pattern', 'pay', 'pcb', 'pediatr', 'pediatrician',
#        'penetr', 'pension', 'percept', 'perform', 'periodont', 'perk',
#        'person', 'persuas', 'pet', 'pharmaceut', 'phenomenon', 'phone',
#        'physic', 'physician', 'piec', 'pipelin', 'plan', 'plane',
#        'planner', 'plant', 'platform', 'play', 'pleas', 'point', 'polici',
#        'popul', 'portfolio', 'posit', 'possess', 'post', 'poster',
#        'potenti', 'power', 'pr', 'practic', 'practition', 'pre', 'precis',
#        'predict', 'prefer', 'prepar', 'preprocess', 'presenc', 'present',
#        'preserv', 'press', 'prevent', 'primari', 'principl', 'print',
#        'priorit', 'problem', 'procedur', 'proceed', 'process', 'procur',
#        'produc', 'product', 'profession', 'program', 'progress',
#        'project', 'promot', 'proper', 'properti', 'propos', 'propuls',
#        'protect', 'protocol', 'prototyp', 'provid', 'psycholog',
#        'psychologist', 'public', 'publish', 'purchas', 'purpos', 'pursu',
#        'qa', 'qualifi', 'qualiti', 'queri', 'question', 'rais', 'rank',
#        'rare', 'rate', 'reach', 'real', 'receiv', 'recognit', 'recommend',
#        'record', 'recoveri', 'recruit', 'reduc', 'refer', 'region',
#        'registr', 'regul', 'regulatori', 'rehabilit', 'relat',
#        'relationship', 'releas', 'relev', 'reliabl', 'remain', 'repetit',
#        'report', 'repres', 'represent', 'reput', 'requir', 'research',
#        'residenti', 'resolut', 'resolv', 'reson', 'resourc', 'respond',
#        'respons', 'restaur', 'result', 'retail', 'retent', 'retir',
#        'retriev', 'return', 'revenu', 'right', 'risk', 'road', 'role',
#        'room', 'root', 'rout', 'run', 'safe', 'safeguard', 'safeti',
#        'sale', 'satisfact', 'save', 'scalabl', 'scale', 'schedul',
#        'school', 'scienc', 'scientif', 'scientist', 'scope', 'screen',
#        'script', 'sculptur', 'seamless', 'search', 'secretari', 'secur',
#        'seek', 'segment', 'select', 'sell', 'sem', 'semi', 'seminar',
#        'senior', 'sens', 'seo', 'serv', 'server', 'servic', 'session',
#        'set', 'shop', 'showcas', 'site', 'situat', 'skill', 'small',
#        'smooth', 'smoothli', 'sobrieti', 'soc', 'social', 'sociolog',
#        'softwar', 'solut', 'solv', 'sourc', 'space', 'special',
#        'specialist', 'specif', 'speech', 'speed', 'spreadsheet', 'sql',
#        'stabil', 'stabl', 'stack', 'staf', 'staff', 'stakehold',
#        'standard', 'statement', 'statist', 'statu', 'stay', 'stock',
#        'storag', 'store', 'strateg', 'strategi', 'strategist',
#        'streamlin', 'strengthen', 'stress', 'strong', 'structur',
#        'struggl', 'student', 'studi', 'studio', 'subcontractor',
#        'subject', 'subscrib', 'subspecialti', 'substanc', 'success',
#        'suit', 'supervis', 'suppli', 'supplier', 'support', 'surgeon',
#        'surgeri', 'surgic', 'sustain', 'swallow', 'tailor', 'talent',
#        'target', 'task', 'tax', 'teach', 'teacher', 'team', 'technic',
#        'technician', 'techniqu', 'technolog', 'term', 'territori', 'test',
#        'tester', 'testimoni', 'therapi', 'therapist', 'threat', 'time',
#        'titl', 'tool', 'tooth', 'track', 'trade', 'trademark', 'traffic',
#        'train', 'trainer', 'transact', 'transform', 'transit', 'translat',
#        'transmiss', 'transport', 'treasuri', 'treat', 'treatment',
#        'trend', 'trial', 'troubleshoot', 'ui', 'ultim', 'unauthor',
#        'understand', 'uniqu', 'unit', 'unstructur', 'updat', 'urban',
#        'urgent', 'usabl', 'use', 'user', 'util', 'ux', 'valid', 'valu',
#        'valuabl', 'variou', 'vendor', 'ventil', 'venu', 'verifi',
#        'veterinarian', 'video', 'visibl', 'vision', 'visit', 'visual',
#        'volum', 'vulner', 'water', 'way', 'wealth', 'web', 'websit',
#        'wed', 'wide', 'wirefram', 'wireless', 'work', 'workflow',
#        'workplac', 'worth', 'write', 'writer'], dtype=object)

# %%
def match_resume_to_jobs(resume_text, top_n=5):
    """
    Match a candidate's resume text to job descriptions based on cosine similarity.
    """
    resume_text_clean = resume_text.lower()
    resume_text_clean = re.sub(r"[^a-z\s]", " ", resume_text_clean)
    resume_text_clean = re.sub(r"\s+", " ", resume_text_clean).strip()
    resume_vector = tfidf.transform([resume_text_clean])
    # cosine_sim = cosine_similarity(resume_vector, tfidf_matrix).flatten()
    cosine_sim = cosine_similarity(resume_vector, X).flatten()
    top_indices = cosine_sim.argsort()[-top_n:][::-1]

    print("\nTop matching job descriptions:")
    for idx in top_indices:
        print(f"Job ID: {df['Job Id'].iloc[idx]}, Similarity: {cosine_sim[idx]:.4f}")
        print("Job Title:", df["Job Title"].iloc[idx])
        print("Job Description Preview:", df["Job Description"].iloc[idx][:200], "...\n")

# Test the resume matching function with an example resume
example_resume = """
Experienced digital marketer with expertise in social media strategy,
content creation, and data analytics. Proven track record of boosting engagement
and driving conversions through innovative campaigns.
"""
match_resume_to_jobs(example_resume, top_n=3)
# Out:
# Top matching job descriptions:
# Job ID: 531124294656644, Similarity: 0.3064
# Job Title: Marketing Specialist
# Job Description Preview: Content Marketing Managers oversee the creation and distribution of content to attract and engage customers. They develop content strategies, manage content teams, and track performance metrics to opt ...
#
# Job ID: 2172401881813554, Similarity: 0.3064
# Job Title: Marketing Specialist
# Job Description Preview: Content Marketing Managers oversee the creation and distribution of content to attract and engage customers. They develop content strategies, manage content teams, and track performance metrics to opt ...
#
# Job ID: 2657422898340473, Similarity: 0.3064
# Job Title: Marketing Specialist
# Job Description Preview: Content Marketing Managers oversee the creation and distribution of content to attract and engage customers. They develop content strategies, manage content teams, and track performance metrics to opt ...

# %% [markdown]
# # **8. Encode Target Variable (Job Titles)**

# %%
le = LabelEncoder()
y = le.fit_transform(df["Job Title"])
print("Number of unique job titles:", len(le.classes_))
print("Sample job title classes:", le.classes_[:10])
# Out:
# Number of unique job titles: 143
# Sample job title classes: ['Account Director' 'Account Executive' 'Account Manager' 'Accountant'
#  'Administrative Assistant' 'Aerospace Engineer' 'Architect'
#  'Architectural Designer' 'Art Director' 'Art Teacher']

# %% [markdown]
# # **9. Train-Test Split**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42, stratify=y)

# %%
print("Training set shape:", X_train.shape)
# Out:
# Training set shape: (11727, 931)

# %%
print("Test set shape:", X_test.shape)
# Out:
# Test set shape: (2932, 931)

# %% [markdown]
# # **10. Model Training and Analysis**

# %% [markdown]
# ### Train a Decision Tree Classifier

# %%
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)
y_pred_dt = dt_model.predict(X_test)
dt_accuracy = accuracy_score(y_test, y_pred_dt)
print("Decision Tree Accuracy:", dt_accuracy)
print("Decision Tree Classification Report:")
print(classification_report(y_test, y_pred_dt, target_names=le.classes_))
# Out:
# Decision Tree Accuracy: 1.0
# Decision Tree Classification Report:
#                                      precision    recall  f1-score   support
#
#                    Account Director       1.00      1.00      1.00        12
#                   Account Executive       1.00      1.00      1.00        21
#                     Account Manager       1.00      1.00      1.00        26
#                          Accountant       1.00      1.00      1.00        17
#            Administrative Assistant       1.00      1.00      1.00        33
#                  Aerospace Engineer       1.00      1.00      1.00        20
#                           Architect       1.00      1.00      1.00        27
#              Architectural Designer       1.00      1.00      1.00        13
#                        Art Director       1.00      1.00      1.00        20
#                         Art Teacher       1.00      1.00      1.00        22
#                  Back-End Developer       1.00      1.00      1.00        13
#                    Brand Ambassador       1.00      1.00      1.00        19
#                       Brand Manager       1.00      1.00      1.00        20
#                    Business Analyst       1.00      1.00      1.00        22
#        Business Development Manager       1.00      1.00      1.00        17
#                   Chemical Engineer       1.00      1.00      1.00        18
#                      Civil Engineer       1.00      1.00      1.00        26
#                      Content Writer       1.00      1.00      1.00        25
#                          Copywriter       1.00      1.00      1.00        18
#            Customer Service Manager       1.00      1.00      1.00        21
#     Customer Service Representative       1.00      1.00      1.00        13
#            Customer Success Manager       1.00      1.00      1.00        21
#         Customer Support Specialist       1.00      1.00      1.00        34
#                        Data Analyst       1.00      1.00      1.00        29
#                       Data Engineer       1.00      1.00      1.00        19
#                    Data Entry Clerk       1.00      1.00      1.00        15
#                      Data Scientist       1.00      1.00      1.00        11
#              Database Administrator       1.00      1.00      1.00        23
#                  Database Developer       1.00      1.00      1.00        10
#                    Dental Hygienist       1.00      1.00      1.00        19
#        Digital Marketing Specialist       1.00      1.00      1.00        49
#                 Electrical Designer       1.00      1.00      1.00        17
#                 Electrical Engineer       1.00      1.00      1.00        20
#          Email Marketing Specialist       1.00      1.00      1.00        20
#            Environmental Consultant       1.00      1.00      1.00        27
#              Environmental Engineer       1.00      1.00      1.00        16
#                   Event Coordinator       1.00      1.00      1.00        28
#                       Event Manager       1.00      1.00      1.00         6
#                       Event Planner       1.00      1.00      1.00        32
#                 Executive Assistant       1.00      1.00      1.00        40
#                       Family Lawyer       1.00      1.00      1.00        15
#           Family Nurse Practitioner       1.00      1.00      1.00        19
#                     Finance Manager       1.00      1.00      1.00        17
#                   Financial Advisor       1.00      1.00      1.00        35
#                   Financial Analyst       1.00      1.00      1.00        24
#                Financial Controller       1.00      1.00      1.00        13
#                   Financial Planner       1.00      1.00      1.00         5
#                 Front-End Developer       1.00      1.00      1.00        18
#                  Front-End Engineer       1.00      1.00      1.00        11
#                    Graphic Designer       1.00      1.00      1.00        28
#                      HR Coordinator       1.00      1.00      1.00        34
#                       HR Generalist       1.00      1.00      1.00         6
#                          HR Manager       1.00      1.00      1.00        19
#             Human Resources Manager       1.00      1.00      1.00        18
#                    IT Administrator       1.00      1.00      1.00         6
#                          IT Manager       1.00      1.00      1.00        12
#               IT Support Specialist       1.00      1.00      1.00        20
#                   Interior Designer       1.00      1.00      1.00        25
#                   Inventory Analyst       1.00      1.00      1.00         6
#                  Investment Advisor       1.00      1.00      1.00         7
#                  Investment Analyst       1.00      1.00      1.00        21
#                   Investment Banker       1.00      1.00      1.00        25
#                      Java Developer       1.00      1.00      1.00        15
#                 Key Account Manager       1.00      1.00      1.00         6
#                 Landscape Architect       1.00      1.00      1.00        30
#                  Landscape Designer       1.00      1.00      1.00        13
#                     Legal Assistant       1.00      1.00      1.00        29
#                       Legal Counsel       1.00      1.00      1.00        19
#                     Legal Secretary       1.00      1.00      1.00        12
#                 Litigation Attorney       1.00      1.00      1.00        27
#                      Market Analyst       1.00      1.00      1.00         4
#             Market Research Analyst       1.00      1.00      1.00        19
#                   Marketing Analyst       1.00      1.00      1.00        22
#               Marketing Coordinator       1.00      1.00      1.00        19
#                  Marketing Director       1.00      1.00      1.00        19
#                   Marketing Manager       1.00      1.00      1.00        28
#                Marketing Specialist       1.00      1.00      1.00        18
#                 Mechanical Designer       1.00      1.00      1.00        19
#                 Mechanical Engineer       1.00      1.00      1.00        25
#               Network Administrator       1.00      1.00      1.00        30
#                     Network Analyst       1.00      1.00      1.00         6
#                    Network Engineer       1.00      1.00      1.00        43
#         Network Security Specialist       1.00      1.00      1.00        17
#                  Network Technician       1.00      1.00      1.00        13
#                       Nurse Manager       1.00      1.00      1.00        20
#                  Nurse Practitioner       1.00      1.00      1.00        21
#              Occupational Therapist       1.00      1.00      1.00        22
#                      Office Manager       1.00      1.00      1.00        21
#                  Operations Manager       1.00      1.00      1.00        28
#                           Paralegal       1.00      1.00      1.00        19
#                        Pediatrician       1.00      1.00      1.00        20
#                  Personal Assistant       1.00      1.00      1.00         8
# Pharmaceutical Sales Representative       1.00      1.00      1.00        20
#                  Physical Therapist       1.00      1.00      1.00        19
#                 Physician Assistant       1.00      1.00      1.00        17
#                    Process Engineer       1.00      1.00      1.00        11
#             Procurement Coordinator       1.00      1.00      1.00         7
#                 Procurement Manager       1.00      1.00      1.00        36
#              Procurement Specialist       1.00      1.00      1.00        27
#                    Product Designer       1.00      1.00      1.00         6
#                     Product Manager       1.00      1.00      1.00        10
#                 Project Coordinator       1.00      1.00      1.00        24
#                     Project Manager       1.00      1.00      1.00        27
#                        Psychologist       1.00      1.00      1.00        21
#         Public Relations Specialist       1.00      1.00      1.00        15
#                    Purchasing Agent       1.00      1.00      1.00        30
#                          QA Analyst       1.00      1.00      1.00        17
#                         QA Engineer       1.00      1.00      1.00         6
#           Quality Assurance Analyst       1.00      1.00      1.00        22
#                    Registered Nurse       1.00      1.00      1.00        21
#                    Research Analyst       1.00      1.00      1.00        24
#                  Research Scientist       1.00      1.00      1.00        21
#                      SEM Specialist       1.00      1.00      1.00        18
#                      SEO Specialist       1.00      1.00      1.00        21
#                     Sales Associate       1.00      1.00      1.00         5
#                    Sales Consultant       1.00      1.00      1.00        18
#                       Sales Manager       1.00      1.00      1.00        18
#                Sales Representative       1.00      1.00      1.00        37
#            Social Media Coordinator       1.00      1.00      1.00        13
#                Social Media Manager       1.00      1.00      1.00        33
#                       Social Worker       1.00      1.00      1.00        22
#                  Software Architect       1.00      1.00      1.00        18
#                  Software Developer       1.00      1.00      1.00         7
#                   Software Engineer       1.00      1.00      1.00        52
#                     Software Tester       1.00      1.00      1.00        38
#                    Speech Therapist       1.00      1.00      1.00        17
#                 Structural Engineer       1.00      1.00      1.00        19
#           Substance Abuse Counselor       1.00      1.00      1.00        19
#                Supply Chain Analyst       1.00      1.00      1.00         7
#                Supply Chain Manager       1.00      1.00      1.00        26
#               Systems Administrator       1.00      1.00      1.00        33
#                     Systems Analyst       1.00      1.00      1.00        11
#                      Tax Consultant       1.00      1.00      1.00        20
#                             Teacher       1.00      1.00      1.00        20
#                    Technical Writer       1.00      1.00      1.00        17
#                        UI Developer       1.00      1.00      1.00        28
#                       UX Researcher       1.00      1.00      1.00        18
#                      UX/UI Designer       1.00      1.00      1.00        99
#                       Urban Planner       1.00      1.00      1.00        20
#                        Veterinarian       1.00      1.00      1.00        19
#                        Web Designer       1.00      1.00      1.00        11
#                       Web Developer       1.00      1.00      1.00        19
#                     Wedding Planner       1.00      1.00      1.00        13
#
#                            accuracy                           1.00      2932
#                           macro avg       1.00      1.00      1.00      2932
#                        weighted avg       1.00      1.00      1.00      2932

# %% [markdown]
# ### Train a Random Forest Classifier

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)
rf_accuracy = accuracy_score(y_test, y_pred_rf)
print("Random Forest Accuracy:", rf_accuracy)
print("Random Forest Classification Report:")
print(classification_report(y_test, y_pred_rf, target_names=le.classes_))
# Out:
# Random Forest Accuracy: 1.0
# Random Forest Classification Report:
#                                      precision    recall  f1-score   support
#
#                    Account Director       1.00      1.00      1.00        12
#                   Account Executive       1.00      1.00      1.00        21
#                     Account Manager       1.00      1.00      1.00        26
#                          Accountant       1.00      1.00      1.00        17
#            Administrative Assistant       1.00      1.00      1.00        33
#                  Aerospace Engineer       1.00      1.00      1.00        20
#                           Architect       1.00      1.00      1.00        27
#              Architectural Designer       1.00      1.00      1.00        13
#                        Art Director       1.00      1.00      1.00        20
#                         Art Teacher       1.00      1.00      1.00        22
#                  Back-End Developer       1.00      1.00      1.00        13
#                    Brand Ambassador       1.00      1.00      1.00        19
#                       Brand Manager       1.00      1.00      1.00        20
#                    Business Analyst       1.00      1.00      1.00        22
#        Business Development Manager       1.00      1.00      1.00        17
#                   Chemical Engineer       1.00      1.00      1.00        18
#                      Civil Engineer       1.00      1.00      1.00        26
#                      Content Writer       1.00      1.00      1.00        25
#                          Copywriter       1.00      1.00      1.00        18
#            Customer Service Manager       1.00      1.00      1.00        21
#     Customer Service Representative       1.00      1.00      1.00        13
#            Customer Success Manager       1.00      1.00      1.00        21
#         Customer Support Specialist       1.00      1.00      1.00        34
#                        Data Analyst       1.00      1.00      1.00        29
#                       Data Engineer       1.00      1.00      1.00        19
#                    Data Entry Clerk       1.00      1.00      1.00        15
#                      Data Scientist       1.00      1.00      1.00        11
#              Database Administrator       1.00      1.00      1.00        23
#                  Database Developer       1.00      1.00      1.00        10
#                    Dental Hygienist       1.00      1.00      1.00        19
#        Digital Marketing Specialist       1.00      1.00      1.00        49
#                 Electrical Designer       1.00      1.00      1.00        17
#                 Electrical Engineer       1.00      1.00      1.00        20
#          Email Marketing Specialist       1.00      1.00      1.00        20
#            Environmental Consultant       1.00      1.00      1.00        27
#              Environmental Engineer       1.00      1.00      1.00        16
#                   Event Coordinator       1.00      1.00      1.00        28
#                       Event Manager       1.00      1.00      1.00         6
#                       Event Planner       1.00      1.00      1.00        32
#                 Executive Assistant       1.00      1.00      1.00        40
#                       Family Lawyer       1.00      1.00      1.00        15
#           Family Nurse Practitioner       1.00      1.00      1.00        19
#                     Finance Manager       1.00      1.00      1.00        17
#                   Financial Advisor       1.00      1.00      1.00        35
#                   Financial Analyst       1.00      1.00      1.00        24
#                Financial Controller       1.00      1.00      1.00        13
#                   Financial Planner       1.00      1.00      1.00         5
#                 Front-End Developer       1.00      1.00      1.00        18
#                  Front-End Engineer       1.00      1.00      1.00        11
#                    Graphic Designer       1.00      1.00      1.00        28
#                      HR Coordinator       1.00      1.00      1.00        34
#                       HR Generalist       1.00      1.00      1.00         6
#                          HR Manager       1.00      1.00      1.00        19
#             Human Resources Manager       1.00      1.00      1.00        18
#                    IT Administrator       1.00      1.00      1.00         6
#                          IT Manager       1.00      1.00      1.00        12
#               IT Support Specialist       1.00      1.00      1.00        20
#                   Interior Designer       1.00      1.00      1.00        25
#                   Inventory Analyst       1.00      1.00      1.00         6
#                  Investment Advisor       1.00      1.00      1.00         7
#                  Investment Analyst       1.00      1.00      1.00        21
#                   Investment Banker       1.00      1.00      1.00        25
#                      Java Developer       1.00      1.00      1.00        15
#                 Key Account Manager       1.00      1.00      1.00         6
#                 Landscape Architect       1.00      1.00      1.00        30
#                  Landscape Designer       1.00      1.00      1.00        13
#                     Legal Assistant       1.00      1.00      1.00        29
#                       Legal Counsel       1.00      1.00      1.00        19
#                     Legal Secretary       1.00      1.00      1.00        12
#                 Litigation Attorney       1.00      1.00      1.00        27
#                      Market Analyst       1.00      1.00      1.00         4
#             Market Research Analyst       1.00      1.00      1.00        19
#                   Marketing Analyst       1.00      1.00      1.00        22
#               Marketing Coordinator       1.00      1.00      1.00        19
#                  Marketing Director       1.00      1.00      1.00        19
#                   Marketing Manager       1.00      1.00      1.00        28
#                Marketing Specialist       1.00      1.00      1.00        18
#                 Mechanical Designer       1.00      1.00      1.00        19
#                 Mechanical Engineer       1.00      1.00      1.00        25
#               Network Administrator       1.00      1.00      1.00        30
#                     Network Analyst       1.00      1.00      1.00         6
#                    Network Engineer       1.00      1.00      1.00        43
#         Network Security Specialist       1.00      1.00      1.00        17
#                  Network Technician       1.00      1.00      1.00        13
#                       Nurse Manager       1.00      1.00      1.00        20
#                  Nurse Practitioner       1.00      1.00      1.00        21
#              Occupational Therapist       1.00      1.00      1.00        22
#                      Office Manager       1.00      1.00      1.00        21
#                  Operations Manager       1.00      1.00      1.00        28
#                           Paralegal       1.00      1.00      1.00        19
#                        Pediatrician       1.00      1.00      1.00        20
#                  Personal Assistant       1.00      1.00      1.00         8
# Pharmaceutical Sales Representative       1.00      1.00      1.00        20
#                  Physical Therapist       1.00      1.00      1.00        19
#                 Physician Assistant       1.00      1.00      1.00        17
#                    Process Engineer       1.00      1.00      1.00        11
#             Procurement Coordinator       1.00      1.00      1.00         7
#                 Procurement Manager       1.00      1.00      1.00        36
#              Procurement Specialist       1.00      1.00      1.00        27
#                    Product Designer       1.00      1.00      1.00         6
#                     Product Manager       1.00      1.00      1.00        10
#                 Project Coordinator       1.00      1.00      1.00        24
#                     Project Manager       1.00      1.00      1.00        27
#                        Psychologist       1.00      1.00      1.00        21
#         Public Relations Specialist       1.00      1.00      1.00        15
#                    Purchasing Agent       1.00      1.00      1.00        30
#                          QA Analyst       1.00      1.00      1.00        17
#                         QA Engineer       1.00      1.00      1.00         6
#           Quality Assurance Analyst       1.00      1.00      1.00        22
#                    Registered Nurse       1.00      1.00      1.00        21
#                    Research Analyst       1.00      1.00      1.00        24
#                  Research Scientist       1.00      1.00      1.00        21
#                      SEM Specialist       1.00      1.00      1.00        18
#                      SEO Specialist       1.00      1.00      1.00        21
#                     Sales Associate       1.00      1.00      1.00         5
#                    Sales Consultant       1.00      1.00      1.00        18
#                       Sales Manager       1.00      1.00      1.00        18
#                Sales Representative       1.00      1.00      1.00        37
#            Social Media Coordinator       1.00      1.00      1.00        13
#                Social Media Manager       1.00      1.00      1.00        33
#                       Social Worker       1.00      1.00      1.00        22
#                  Software Architect       1.00      1.00      1.00        18
#                  Software Developer       1.00      1.00      1.00         7
#                   Software Engineer       1.00      1.00      1.00        52
#                     Software Tester       1.00      1.00      1.00        38
#                    Speech Therapist       1.00      1.00      1.00        17
#                 Structural Engineer       1.00      1.00      1.00        19
#           Substance Abuse Counselor       1.00      1.00      1.00        19
#                Supply Chain Analyst       1.00      1.00      1.00         7
#                Supply Chain Manager       1.00      1.00      1.00        26
#               Systems Administrator       1.00      1.00      1.00        33
#                     Systems Analyst       1.00      1.00      1.00        11
#                      Tax Consultant       1.00      1.00      1.00        20
#                             Teacher       1.00      1.00      1.00        20
#                    Technical Writer       1.00      1.00      1.00        17
#                        UI Developer       1.00      1.00      1.00        28
#                       UX Researcher       1.00      1.00      1.00        18
#                      UX/UI Designer       1.00      1.00      1.00        99
#                       Urban Planner       1.00      1.00      1.00        20
#                        Veterinarian       1.00      1.00      1.00        19
#                        Web Designer       1.00      1.00      1.00        11
#                       Web Developer       1.00      1.00      1.00        19
#                     Wedding Planner       1.00      1.00      1.00        13
#
#                            accuracy                           1.00      2932
#                           macro avg       1.00      1.00      1.00      2932
#                        weighted avg       1.00      1.00      1.00      2932

# %% [markdown]
# ### Plot and save confusion matrix for Random Forest model

# %%
cm = confusion_matrix(y_test, y_pred_rf)
plt.figure(figsize=(35, 25))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.title("Random Forest Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.tight_layout()
plt.savefig("random_forest_confusion_matrix.png")
plt.close()
print("Confusion matrix saved as 'random_forest_confusion_matrix.png'")
# Out:
# Confusion matrix saved as 'random_forest_confusion_matrix.png'

# %% [markdown]
# # **11. Save Artifacts (Models, Vectorizer, Label Encoder)**

# %%
model_dir = "models"
os.makedirs(model_dir, exist_ok=True)

joblib.dump(tfidf, os.path.join(model_dir, "tfidf_vectorizer.pkl"))
joblib.dump(dt_model, os.path.join(model_dir, "decision_tree_model.pkl"))
joblib.dump(rf_model, os.path.join(model_dir, "random_forest_model.pkl"))
joblib.dump(le, os.path.join(model_dir, "label_encoder.pkl"))

print("Artifacts saved successfully in the 'models' directory.")
# Out:
# Artifacts saved successfully in the 'models' directory.
